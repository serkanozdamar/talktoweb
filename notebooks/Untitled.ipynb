# %%
import pandas as pd

df = pd.read_csv("assets/data.txt")

df.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
# my_list = df.duplicated()
# print(type(my_list))

# i = 0
# for my_bool in my_list:
#     if my_bool:
#         df.drop(i, inplace=True)
#     i += 1
# df
df.drop_duplicates()
df[["pulse", "max_pulse"]].corr(columns=["pulse", "max_pulse"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 11
#       1 # my_list = df.duplicated()
#       2 # print(type(my_list))
#       3
#    (...)      8 #     i += 1
#       9 # df
#      10 df.drop_duplicates()
# ---> 11 df.corr(columns=["pulse", "max_pulse"])
#
# TypeError: DataFrame.corr() got an unexpected keyword argument 'columns'

# %%
df  = pd.read_csv("../talktoweb/data/ChicagoCrimeData.csv")

df[["DISTRICT", "BEAT"]].corr()
# Out:
#           DISTRICT      BEAT
# DISTRICT  1.000000  0.918369
# BEAT      0.918369  1.000000

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt
df[["DISTRICT", "WARD"]].plot()
plt.show()
